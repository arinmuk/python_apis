# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pprint import pprint
from skimage import io
url = "http://www.omdbapi.com/?apikey=trilogy&t="

movies = ["Aliens", "Sing", "Moana","Aquaman","The Phantom","Daddy's Home 2","Deadpool 2",]

# %%
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=trilogy"

# %%
for movie in movies:

    response = requests.get(url + movie + api_key)
    #print(response.url)
    data = response.json()
    #pprint(data)
    print(f"Movie was directed by {data['Director']}.")
    print(f"Movie Ratings {data['Ratings']}.")
    posterurl=data['Poster']
    io.imshow(io.imread(posterurl))
    io.show()
# Out:
# Movie was directed by James Cameron.
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '8.4/10'}, {'Source': 'Rotten Tomatoes', 'Value': '99%'}, {'Source': 'Metacritic', 'Value': '84/100'}].
# Movie was directed by Garth Jennings, Christophe Lourdelet(co-director).
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}, {'Source': 'Rotten Tomatoes', 'Value': '72%'}, {'Source': 'Metacritic', 'Value': '59/100'}].
# Movie was directed by Ron Clements, John Musker, Don Hall(co-director), Chris Williams(co-director).
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}, {'Source': 'Rotten Tomatoes', 'Value': '95%'}, {'Source': 'Metacritic', 'Value': '81/100'}].
# Movie was directed by James Wan.
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '7.9/10'}, {'Source': 'Rotten Tomatoes', 'Value': '70%'}, {'Source': 'Metacritic', 'Value': '53/100'}].
# Movie was directed by Simon Wincer.
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '4.9/10'}, {'Source': 'Rotten Tomatoes', 'Value': '42%'}].
# Movie was directed by Sean Anders.
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '6.0/10'}, {'Source': 'Rotten Tomatoes', 'Value': '19%'}, {'Source': 'Metacritic', 'Value': '30/100'}].
# Movie was directed by David Leitch.
# Movie Ratings [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '83%'}, {'Source': 'Metacritic', 'Value': '66/100'}].
